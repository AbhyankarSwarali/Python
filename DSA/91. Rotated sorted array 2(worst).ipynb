# %%
l = [ 7,7,7,7,7,7,7,7,1,2,3,4,5,7,7]
l.sort()
target = 3

def check_element(l,target): 
    if target in l: 
        return True
    else: 
        return False

print(check_element(l,target))
# Out:
# True
