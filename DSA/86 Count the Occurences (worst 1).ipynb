# %%
def occurence_count(l,target): 
    n = len(l)
    count = 0
    for i in range(n): 
        if l[i] == target: 
            count += 1
    return count

l = [1,2,3,3,3,3,3,5,6,8,9,9,10]
target = 3
print(occurence_count(l,target))
# Out:
# 5
