# %%
l = [11,15,20,1,4,5,6,8,9,10]
target = 8

def find(l,target): 
    n = len(l)
    for i in range(n): 
        if l[i] == target: 
            return i
    return -1

print(find(l,target))
# Out:
# 7
